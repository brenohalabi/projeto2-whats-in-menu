# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#Menu Ds
df_dish = pd.read_csv('./Dish.csv')
df_dish
# Out:
#             id                                               name  \
# 0            1                         Consomme printaniere royal
# 1            2                                      Chicken gumbo
# 2            3                                Tomato aux croutons
# 3            4                                    Onion au gratin
# 4            5                                        St. Emilion
# ...        ...                                                ...
# 426735  519144                    Vanilla and chocolate ice cream
# 426736  519169  Mutton soup with Porto wine Cream soup Chicago...
# 426737  519170  Moussaka Oriental style Montana roebucks saddl...
# 426738  519171                                       Prima Classe
# 426739  519172                  Comandante Cap. Sup. Mario Crepaz
#
#         description  menus_appeared  times_appeared  first_appeared  \
# 0               NaN               8               8            1897
# ...

# %%
df_dish_sorted = df_dish.sort_values(by=['times_appeared'], ascending=False)
df_dish_sorted_top15 = df_dish_sorted.head(15).copy()

plt.figure(figsize=(12,6))
plt.xticks(rotation=75)
#plt.title(schema.Country)
sns.barplot(x=df_dish_sorted_top15.name, y=df_dish_sorted_top15.times_appeared);

# %%
df_dish_menu_sorted = df_dish.sort_values(by=['menus_appeared'], ascending=False)
df_dish_menu_sorted_top15 = df_dish_menu_sorted.head(15).copy()

plt.figure(figsize=(12,6))
plt.xticks(rotation=75)
sns.barplot(x=df_dish_menu_sorted_top15.name, y=df_dish_menu_sorted_top15.menus_appeared);
